# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/My Drive')

# %%
df=pd.read_csv("u.data",sep='\t',names=["user_id","item_id","rating","timestamp"])

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
df.shape
# Out:
# (100000, 4)

# %%
df['user_id'].nunique()
# Out:
# 943

# %%
df['item_id'].nunique()
# Out:
# 1682

# %%
#timestamp not relable
import warnings

# %%
ekaur=pd.read_csv("u.item",sep='\|',header=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
ekaur.head()
# Out:
#    0                  1            2   3   ... 20  21  22  23
# 0   1   Toy Story (1995)  01-Jan-1995 NaN  ...  0   0   0   0
# 1   2   GoldenEye (1995)  01-Jan-1995 NaN  ...  0   1   0   0
# 2   3  Four Rooms (1995)  01-Jan-1995 NaN  ...  0   1   0   0
# 3   4  Get Shorty (1995)  01-Jan-1995 NaN  ...  0   0   0   0
# 4   5     Copycat (1995)  01-Jan-1995 NaN  ...  0   1   0   0
#
# [5 rows x 24 columns]

# %%
ekaur.shape
# Out:
# (1682, 24)

# %%
#item_id se jodna padega

# %%
ekaur=ekaur[[0,1]]

# %%
ekaur.shape
# Out:
# (1682, 2)

# %%
ekaur.columns=["item_id","title"]

# %%
ekaur.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
# Now merging through the column Item_id

# %%
#use merge and it takes On as the paramter ie: the key

# %%
df = pd.merge(df,ekaur,on="item_id")

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp         title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %%
df.tail()
# Out:
#        user_id  ...                                              title
# 99995      840  ...                                  Mamma Roma (1962)
# 99996      655  ...                             Eighth Day, The (1996)
# 99997      655  ...                                  Girls Town (1996)
# 99998      655  ...  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999      655  ...                                    Dadetown (1995)
#
# [5 rows x 5 columns]

# %%
#Explaoratory data analysis Now

# %%
df.shape
# Out:
# (100000, 5)

# %%
df.groupby("title").mean()['rating'].sort_values(ascending=False)
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Prefontaine (1997)                              5.0
# Santa with Muscles (1996)                       5.0
# Star Kid (1997)                                 5.0
# Someone Else's America (1995)                   5.0
#                                                ...
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# JLG/JLG - autoportrait de d�cembre (1994)       1.0
# Daens (1992)                                    1.0
# Butterfly Kiss (1995)                           1.0
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# Name: rating, Length: 1664, dtype: float64

# %%
a=10

# %%
df.shape
# Out:
# (100000, 5)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp         title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %%
#its after the merging

# %%
sns.set_style('white')

# %%
df.groupby('title').mean()['rating'].sort_values(ascending=False)
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Prefontaine (1997)                              5.0
# Santa with Muscles (1996)                       5.0
# Star Kid (1997)                                 5.0
# Someone Else's America (1995)                   5.0
#                                                ...
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# JLG/JLG - autoportrait de d�cembre (1994)       1.0
# Daens (1992)                                    1.0
# Butterfly Kiss (1995)                           1.0
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# Name: rating, Length: 1664, dtype: float64

# %%
ratings=pd.DataFrame(df.groupby('title').mean()['rating'])

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['number_of_ratings']=df.groupby('title').count()['rating']

# %%
ratings
# Out:
#                                          rating  number_of_ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# � k�ldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings['number_of_ratings'],bins=60)
plt.show()

# %%
plt.hist(ratings['rating'],bins=50)
plt.show(
    
)

# %%
sns.jointplot(x='rating',y='number_of_ratings',data=ratings,alpha=0.6)

# %%
movie_matrix=df.pivot_table(index='user_id',columns='title',values='rating')

# %%
movie_matrix.head()
# Out:
# user_id                    1    2    3    4    5    ...  939  940  941  942  943
# title                                               ...
# 'Til There Was You (1997)  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN
# 1-900 (1994)               NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (1996)      2.0  NaN  NaN  NaN  2.0  ...  NaN  NaN  NaN  NaN  NaN
# 12 Angry Men (1957)        5.0  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN
# 187 (1997)                 NaN  NaN  2.0  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 943 columns]

# %%
movie_matrix
# Out:
# title    'Til There Was You (1997)  ...  � k�ldum klaka (Cold Fever) (1994)
# user_id                             ...
# 1                              NaN  ...                                 NaN
# 2                              NaN  ...                                 NaN
# 3                              NaN  ...                                 NaN
# 4                              NaN  ...                                 NaN
# 5                              NaN  ...                                 NaN
# ...                            ...  ...                                 ...
# 939                            NaN  ...                                 NaN
# 940                            NaN  ...                                 NaN
# 941                            NaN  ...                                 NaN
# 942                            NaN  ...                                 NaN
# 943                            NaN  ...                                 NaN
#
# ...

# %%
def predict(movie_name):
  movie_user_ratings=movie_matrix[movie_name]
  simillar=movie_matrix.corrwith(movie_user_ratings)
  corr_mov=pd.DataFrame(simillar,columns=['Correlation'])
  corr_mov.dropna(inplace=True)
  corr_mov=corr_mov.join(ratings['number_of_ratings'])
  answer=corr_mov[corr_mov['number_of_ratings']>50].sort_values('Correlation',ascending=False)
  return answer

# %%
predict('Titanic (1997)')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                                 Correlation  number_of_ratings
# title
# Titanic (1997)                                     1.000000                350
# Adventures of Robin Hood, The (1938)               0.597532                 67
# Mallrats (1995)                                    0.580393                 54
# Robin Hood: Men in Tights (1993)                   0.533114                 56
# Manon of the Spring (Manon des sources) (1986)     0.523459                 58
# ...                                                     ...                ...
# Unbearable Lightness of Being, The (1988)         -0.314476                 92
# ...
